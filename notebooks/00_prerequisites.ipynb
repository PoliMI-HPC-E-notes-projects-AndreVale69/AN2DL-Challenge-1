# %% [markdown]
# # Prerequisites
#
# This notebook sets up the environment and installs necessary packages for the AN2DL Challenge 1: Pirate Pain Dataset project.
#
# We will ensure that all required libraries are available for data analysis, preprocessing, and model training.
#
# The following packages will be installed:

# %%
# Print requirements.txt content
# !cat ../requirements.txt
# Out:
# # Jupyter Notebook dependencies
# jupyter
# ipykernel
#
# # Data Science libraries
# numpy
# pandas
# matplotlib
# seaborn
# scikit-learn

# %%
# !pip install -r ../requirements.txt

# %%
import subprocess

try:
    # Check for NVIDIA GPU
    result = subprocess.run(['nvidia-smi'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    if result.returncode == 0:
        print("This machine has a GPU available. Installing GPU-specific packages...")
        # !pip install -r ../requirements-gpu.txt
        exit(0)
except FileNotFoundError:
    pass

try:
    # Check for AMD GPU
    result = subprocess.run(['rocm-smi'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    if result.returncode == 0:
        print("This machine has a AMD GPU available. Installing ROCm-specific packages...")
        # !pip install -r ../requirements-rocm.txt
        exit(0)
except FileNotFoundError:
    pass

print("No GPU detected. Skipping GPU-specific package installation.")
# !pip install -r ../requirements-cpu.txt
# Out:
# No GPU detected. Skipping GPU-specific package installation.
# ...
